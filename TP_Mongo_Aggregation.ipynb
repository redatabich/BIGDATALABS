# %% [markdown]
# <a href="https://colab.research.google.com/github/redatabich/BIGDATALABS/blob/main/TP_Mongo_Aggregation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pymongo

# %%
from pymongo import MongoClient

uri = "mongodb+srv://redatabich_db_user:JYzw0sqnqZCa5xg4@cluster0.at0jwuf.mongodb.net/"
client = MongoClient(uri)
# Accéder à la base de données
db = client["BankDB"]
transactions_collection = db["transactions"]
# Vérification de la connexion
print("Connexion à MongoDB Atlas réussie!")
# Out:
# Connexion à MongoDB Atlas réussie!

# %%
#creer un pipeline d’ Aggregation pour calculer le montant total transaction par type
pipeline = [{"$group": {"_id": "$Transaction Type", "totalAmount": {"$sum": "$Transaction Amount"}}}]
# executer la requete d’agrégation
result = transactions_collection.aggregate(pipeline)
# afficher les resultats
for doc in result:
 print(f"Transaction Type: {doc['_id']}, Total Amount: {doc['totalAmount']}")
# Out:
# Transaction Type: Deposit, Total Amount: 252042.62
# Transaction Type: Withdrawal, Total Amount: 227346.12
# Transaction Type: Transfer, Total Amount: 291776.55

# %%
doc = transactions_collection.find_one()
print(doc)
# Out:
# {'_id': ObjectId('696f54ee31a8e1e175105607'), 'Transaction ID': 'TXN9520068950', 'Sender Account ID': 'ACC14994', 'Receiver Account ID': 'ACC16656', 'Transaction Amount': 495.9, 'Transaction Type': 'Deposit', 'Timestamp': '2025-01-17 10:14:00', 'Transaction Status': 'Failed', 'Fraud Flag': True, 'Geolocation (Latitude/Longitude)': '34.0522 N, -74.006 W', 'Device Used': 'Desktop', 'Network Slice ID': 'Slice3', 'Latency (ms)': 10, 'Slice Bandwidth (Mbps)': 179, 'PIN Code': 3075}

# %%
# !cp /content/TP_Mongo_Aggregation.ipynb .
# Out:
# cp: cannot stat '/content/TP_Mongo_Aggregation.ipynb': No such file or directory
